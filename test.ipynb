# %%
from maze import Maze
from policy import Policy
from reinforce_mcpg import Reinforcer
import torch
import random

# %%
maze = Maze()

# %%
in_dim = 2
out_dim = 4
H = 50

pol = Policy(in_dim, out_dim, H)

# %%
step_size = .1
discount = .9

reinforcer = Reinforcer(maze, pol, step_size, discount)

# %%
pol = reinforcer.reinforce()
print("policy:",pol)
# Out:
# policy: <policy.Policy object at 0x117a37c18>

# %%
init_state = random.choice(maze.state_space(initial=True))

# %%
state = init_state
print("initial state:", state)
for i in range(100):
    if not maze.terminal_state(state):
        state_t = torch.tensor(state, dtype=torch.float)
        action_vec = pol(state_t)
        print("action vec:", action_vec)
        action_index = reinforcer.max_action(action_vec, state)
        print("action index:", action_index)
        action = maze.get_action(state, action_index)
        print("action: ", action)
        state = maze.successor(state, action)[0]
        print("state:", state)
    else:
        print("terminal state found")
        break
# Out:
# initial state: (0, 0)
# action vec: tensor([0.2500, 0.2500, 0.2500, 0.2500], grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (1, 0)
# action vec: tensor([1.5844e-06, 1.0000e+00, 1.5844e-06, 1.5844e-06],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (2, 0)
# action vec: tensor([4.6000e-09, 1.0000e+00, 4.6000e-09, 4.6000e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (3, 0)
# action vec: tensor([9.2438e-10, 1.0000e+00, 9.2438e-10, 9.2438e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (4, 0)
# action vec: tensor([7.3808e-10, 1.0000e+00, 7.3808e-10, 7.3808e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
# action vec: tensor([1.1228e-09, 1.0000e+00, 1.1228e-09, 1.1228e-09],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (-1, 0)
# state: (5, 0)
# action vec: tensor([8.7007e-10, 1.0000e+00, 8.7007e-10, 8.7007e-10],
#        grad_fn=<SoftmaxBackward>)
# action index: 1
# action:  (1, 0)
# state: (6, 0)
